# %%
pip install transformers[torch]

# %%
pip install nervaluate

# %%
pip install tensorrt

# %%
# !python "//content//drive//MyDrive//DeepLearning_Project//LEGAL.py" \
--ds_train_path "//content//drive//MyDrive//DeepLearning_Project//NER_TRAIN_JUDGEMENT.json" \
--ds_valid_path "//content//drive//MyDrive//DeepLearning_Project//NER_DEV_JUDGEMENT.json" \
--output_folder "//content//drive//MyDrive//DeepLearning_Project//" \
--batch 1 \
--num_epochs 5 \
--lr 1e-4 \
--weight_decay 0.01 \
--warmup_ratio 0.06

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
